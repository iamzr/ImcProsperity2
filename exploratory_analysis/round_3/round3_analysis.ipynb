# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
from pathlib import Path

# %%
data_folder_path = Path("/home/zr/code/trading_project/exploratory_analysis/Prosperity2Data")

# %%
x = np.loadtxt(data_folder_path / 'round-3-island-data-bottle/prices_round_3_day_0.csv', delimiter=';', skiprows=1, dtype=str)
x1 = np.loadtxt(data_folder_path / 'round-3-island-data-bottle/prices_round_3_day_1.csv', delimiter=';', skiprows=1, dtype=str)
x2 = np.loadtxt(data_folder_path / 'round-3-island-data-bottle/prices_round_3_day_2.csv', delimiter=';', skiprows=1, dtype=str)

x = np.vstack((x, x1, x2))
# day;timestamp;product;bid_price_1;bid_volume_1;bid_price_2;bid_volume_2;bid_price_3;bid_volume_3;ask_price_1;ask_volume_1;ask_price_2;ask_volume_2;ask_price_3;ask_volume_3;mid_price;profit_and_loss
CHOCOLATE = x[np.argwhere(x[:, 2] == 'CHOCOLATE').flatten(), :][:, [0,1,3,4,9,10,15]].astype(float)
STRAWBERRIES = x[np.argwhere(x[:, 2] == 'STRAWBERRIES').flatten(), :][:, [0,1,3,4,9,10,15]].astype(float)
ROSES = x[np.argwhere(x[:, 2] == 'ROSES').flatten(), :][:, [0,1,3,4,9,10,15]].astype(float)
GIFT_BASKET = x[np.argwhere(x[:, 2] == 'GIFT_BASKET').flatten(), :][:, [0,1,3,4,9,10,15]].astype(float)

bid_price_1 = 2
bid_volume_1 = 3
ask_price_1 = 4
ask_volume_1 = 5
mid_price = 6

print(CHOCOLATE.shape)
print(CHOCOLATE[:,bid_price_1].shape)
# Out:
# (30000, 7)
# (30000,)

# %% [markdown]
# # Making up Baskets

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10, 6))
ax1.plot(GIFT_BASKET[:, mid_price], label='GIFT_BASKET')

y = 4*CHOCOLATE[:, mid_price] + ROSES[:, mid_price] + 6*STRAWBERRIES[:, mid_price]
ax1.plot(y, color='red')

# ax3 = ax1.twinx()
# humidity_scaled_60 = np.where(humidity > 60, 0, humidity - 60)
# ax3.plot(range(0+shift, len(humidity_scaled_60)+shift), humidity_scaled_60, color='green')

# fig.tight_layout()

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10, 6))
difference = GIFT_BASKET[:, mid_price] - y
print(np.mean(difference))
ax1.plot(difference, label='difference')
# Out:
# 379.4904833333333

# %%
difference.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 difference.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'
